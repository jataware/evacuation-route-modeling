# %%
from functools import partial
import geopandas as gpd
import pandas as pd
import math
import numpy as np
import shapely
from shapely.geometry import Point
import googlemaps
import pgeocode
import pyproj

# %%
start_lat, start_lon = (50.4019514, 30.3926109)
disaster_radius_km = 150
flight_radius_km = disaster_radius_km + 200
travel_modes = ["DRIVING", "WALKING"]
travel_mode = travel_modes[0]

CITY_FILE = "cities1000.txt"

# %%
# Used to "quickly" limit distance to a certain bounding box so we're not comparing distances for every city on Earth
# Not particularly accurate, but good enough for the purpose
def reverse_haversine(start_location, dist_km, direction="N"):
    dir_lookup = {
        "N": 0,
        "E": math.pi/2,
        "S": math.pi,
        "W": -math.pi/2,
    }
    result = np.radians(start_location)
    lat, long = result
    dist = dist_km / pgeocode.EARTH_RADIUS
    theta = dir_lookup[direction]  # Direction in radians
    
    lat2 = math.asin(
        (math.sin(lat) * math.cos(dist)) + (math.cos(lat) * math.sin(dist) * math.cos(theta))
    )
    long2 = (
        long + math.atan2((math.sin(theta) * math.sin(dist) * math.cos(lat)),
        (math.cos(dist) - (math.sin(lat) * math.sin(lat2))))
    )
    
    return math.degrees(lat2), math.degrees(long2)

# %%
loc = (start_lat, start_lon)
bounds = {
    "north": reverse_haversine(loc, flight_radius_km * 2, "N")[0], 
    "east": reverse_haversine(loc, flight_radius_km * 2, "E")[1],
    "south": reverse_haversine(loc, flight_radius_km * 2, "S")[0], 
    "west": reverse_haversine(loc, flight_radius_km * 2, "W")[1],
}

# %%
bounds
# Out:
# {'north': 56.69719374845024,
#  'east': 40.21174911830772,
#  'south': 44.10670905154976,
#  'west': 20.57347268169228}

# %% [markdown]
# https://download.geonames.org/export/dump/cities1000.zip
# http://download.geonames.org/export/dump/readme.txt

# %%
city_df = pd.read_csv(
    CITY_FILE, 
    sep="\t", 
    header=0,
    names=[
         "geonameid", 
 "name", 
 "asciiname", 
 "alternatenames", 
 "latitude", 
 "longitude", 
 "feature class", 
 "feature code", 
 "country code", 
 "cc2", 
 "admin1 code", 
 "admin2 code", 
 "admin3 code", 
 "admin4 code", 
 "population", 
 "elevation", 
 "dem", 
 "timezone", 
 "modification date", 

    ]
)
# Out:
# /tmp/ipykernel_269017/2045376136.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   city_df = pd.read_csv(

# %%
proj = pyproj.Proj(f"+proj=aeqd +units=km +lat_0={start_lat} +lon_0={start_lon}")
proj_df = gpd.GeoDataFrame(
    city_df, 
    geometry=gpd.points_from_xy(city_df.latitude, city_df.longitude),
    crs=pyproj.CRS("EPSG:4326"),
)

# %% [markdown]
# Fast function to limit cities to those that MIGHT be in range

# %%
proj_df = proj_df.query(
    f"not (latitude > {bounds['north']} or longitude > {bounds['east']} or latitude < {bounds['south']} or longitude < {bounds['west']})"
)

# %%
proj_df.sort_values("longitude")
# Out:
#         geonameid                    name               asciiname  \
# 107339     785671                   Sopot                   Sopot
# 98787      763659  Nowe Miasto nad Pilicą  Nowe Miasto nad Pilica
# 98928      766307      Lidzbark Warmiński      Lidzbark Warminski
# 109934     549302               Khrabrovo               Khrabrovo
# 107382     787391                 Orlovat                 Orlovat
# ...           ...                     ...                     ...
# 108974     511435          Pereleshinskiy          Pereleshinskiy
# 110219     559736                  Gornyy                  Gornyy
# 110042     553427             Kamenolomni             Kamenolomni
# 109541     535253                  Likhoy                  Likhoy
# 110810     583358      Aleksandro-Nevskiy      Aleksandro-Nevskiy
#
#                                            alternatenames  latitude  \
# 107339  Opstina Sopot,Opština Sopot,Sopot,Sopot Veligr...  44.51972
# 98787   Nove Mjasto nad Pilicom,Nove Mjasto pie Pilica...  51.61812
# 98928   Heilsberg,Heilsburg,Kheyl'sberg,Licbark,Lidzba...  54.12588
# 109934  Chrabroe,Hrabrovo,Khrabrovo,Povunden,Powanden,...  54.89709
# 107382                  Barlad,Borlod,Orlod,Orlovat,Orlód  45.24171
# ...                                                   ...       ...
# 108974  Pereleshinskij,Pereleshinskiy,Perelesjinskij,П...  51.71480
# 110219  Gornaya,Gornaya Shoriya,Gorny,Gornyj,Gornyy,Го...  47.81592
# 110042               Kamenolomni,Kamenolomnya,Каменоломни  47.66853
# 109541                                Likhoj,Likhoy,Лихой  48.12662
# 110810  Aleksandro-Nevskaya,Aleksandro-Nevskij,Aleksan...  53.47510
#
#         longitude feature class feature code country code  cc2 admin1 code  \
# 107339   20.57361             P        PPLA3           RS  NaN          SE
# 98787    20.57619             P        PPLA3           PL   PL          78
# 98928    20.57954             P        PPLA3           PL  NaN          85
# 109934   20.58035             P          PPL           RU  NaN          23
# 107382   20.58089             P          PPL           RS  NaN          VO
# ...           ...           ...          ...          ...  ...         ...
# 108974   40.19530             P          PPL           RU  NaN          86
# 110219   40.20363             P          PPL           RU  NaN          61
# 110042   40.20510             P        PPLA2           RU  NaN          61
# 109541   40.20556             P          PPL           RU  NaN          61
# 110810   40.20950             P          PPL           RU  NaN          62
#
#        admin2 code admin3 code admin4 code  population  elevation  dem  \
# 107339           0       70238         NaN           0        NaN  188
# 98787         1406      140608         NaN        3856        NaN  158
# 98928         2809      280901         NaN       16540        NaN   71
# 109934         NaN         NaN         NaN        2143        NaN    9
# 107382           2       80152         NaN        2159        NaN   76
# ...            ...         ...         ...         ...        ...  ...
# 108974         NaN         NaN         NaN        3257        NaN  161
# 110219         NaN         NaN         NaN        2716        NaN  187
# 110042         NaN         NaN         NaN       12262        NaN   62
# 109541         NaN         NaN         NaN        3102        NaN  117
# 110810         NaN         NaN         NaN        4030        NaN  147
#
#                   timezone modification date                   geometry
# 107339     Europe/Belgrade        2012-04-14  POINT (44.51972 20.57361)
# 98787        Europe/Warsaw        2010-10-01  POINT (51.61812 20.57619)
# 98928        Europe/Warsaw        2014-06-27  POINT (54.12588 20.57954)
# 109934  Europe/Kaliningrad        2016-10-14  POINT (54.89709 20.58035)
# 107382     Europe/Belgrade        2016-10-14  POINT (45.24171 20.58089)
# ...                    ...               ...                        ...
# 108974       Europe/Moscow        2012-01-17  POINT (51.71480 40.19530)
# 110219       Europe/Moscow        2012-01-17  POINT (47.81592 40.20363)
# 110042       Europe/Moscow        2013-05-07  POINT (47.66853 40.20510)
# 109541       Europe/Moscow        2012-01-17  POINT (48.12662 40.20556)
# 110810       Europe/Moscow        2012-01-17  POINT (53.47510 40.20950)
#
# [9439 rows x 20 columns]

# %%
local_azimuthal_projection = f"+proj=aeqd +units=km +lat_0={start_lat} +lon_0={start_lon}"
wgs84_to_aeqd = partial(
    pyproj.transform,
    pyproj.Proj("EPSG:4326"),
    pyproj.Proj(local_azimuthal_projection),
)

# %%
proj_df["geometry"] = proj_df["geometry"].transform(lambda i: Point(wgs84_to_aeqd(i.x, i.y)))
# Out:
# /tmp/ipykernel_269017/1650431364.py:1: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   proj_df["geometry"] = proj_df["geometry"].transform(lambda i: Point(wgs84_to_aeqd(i.x, i.y)))

# %%
proj_df["distance"] = proj_df["geometry"].distance(Point(0, 0))
# Out:
# /tmp/ipykernel_269017/3214616330.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   proj_df["distance"] = proj_df["geometry"].distance(Point(0, 0))

# %%
proj_df.sort_values("distance")
# Out:
#         geonameid                     name                asciiname  \
# 120263    8504651  Sofiyivska Borschagivka  Sofiyivska Borschagivka
# 118318     689487                 Vyshneve                 Vyshneve
# 120265    8504779            Kriukivschina            Kriukivschina
# 120267    8519952                  Chabany                  Chabany
# 119592     706232                   Khotiv                   Khotiv
# ...           ...                      ...                      ...
# 107339     785671                    Sopot                    Sopot
# 107365     786624                     Rača                     Raca
# 107517     792830                 Batočina                 Batocina
# 107319     785013                   Topola                   Topola
# 110044     553514          Kamennomostskiy          Kamennomostskiy
#
#                                            alternatenames  latitude  \
# 120263     Sofievskaja Borshhagovka,Софиевская Борщаговка  50.41005
# 118318  Vishneve,Vishnevoe,Vishnevoye,Vishnjovoe,Vishn...  50.38913
# 120265  Krjukivshhina,Krjukovshhina,Крюковщина,Крюківщина  50.37153
# 120267                      Chabani,Chabany,Чабани,Чабаны  50.34071
# 119592                          Khotiv,Khotov,Хотов,Хотів  50.33069
# ...                                                   ...       ...
# 107339  Opstina Sopot,Opština Sopot,Sopot,Sopot Veligr...  44.51972
# 107365                    Raca,Racha,Rača,racha,Рача,راچا  44.22712
# 107517  Batochina,Batocina,Batočina,batwchyna,batwtshy...  44.15361
# 107319     Topola,Topola Kragujevacka,Topola Kragujevačka  44.25417
# 110044  Kamennomostskaja,Kamennomostskaya,Kamennomosts...  44.28910
#
#         longitude feature class feature code country code  cc2  ...  \
# 120263   30.36724             P          PPL           UA  NaN  ...
# 118318   30.37050             P          PPL           UA  NaN  ...
# 120265   30.36861             P          PPL           UA  NaN  ...
# 120267   30.42356             P          PPL           UA  NaN  ...
# 119592   30.46836             P          PPL           UA  NaN  ...
# ...           ...           ...          ...          ...  ...  ...
# 107339   20.57361             P        PPLA3           RS  NaN  ...
# 107365   20.97754             P        PPLA3           RS  NaN  ...
# 107517   21.08167             P        PPLA3           RS  NaN  ...
# 107319   20.68250             P        PPLA3           RS  NaN  ...
# 110044   40.18800             P          PPL           RU  NaN  ...
#
#        admin2 code admin3 code admin4 code population  elevation  dem  \
# 120263         NaN         NaN         NaN       6571        NaN  163
# 118318         NaN         NaN         NaN      42480        NaN  176
# 120265         NaN         NaN         NaN       3509        NaN  177
# 120267         NaN         NaN         NaN       5100        NaN  188
# 119592         NaN         NaN         NaN       4569        NaN  128
# ...            ...         ...         ...        ...        ...  ...
# 107339           0       70238         NaN          0        NaN  188
# 107365          12       71013         NaN          0        NaN  138
# 107517          12       70076         NaN          0        NaN  109
# 107319          12       71153         NaN          0        NaN  276
# 110044         NaN         NaN         NaN       7585        NaN  453
#
#                timezone modification date                       geometry  \
# 120263      Europe/Kiev        2013-03-17       POINT (-1.80347 0.90117)
# 118318      Europe/Kiev        2021-10-20      POINT (-1.57243 -1.42598)
# 120265      Europe/Kiev        2021-10-27      POINT (-1.70747 -3.38369)
# 120267      Europe/Kiev        2021-10-27       POINT (2.20320 -6.81180)
# 119592      Europe/Kiev        2014-01-12       POINT (5.39355 -7.92410)
# ...                 ...               ...                            ...
# 107339  Europe/Belgrade        2012-04-14  POINT (-779.91992 -603.82713)
# 107365  Europe/Belgrade        2012-04-16  POINT (-751.87345 -640.21006)
# 107517  Europe/Belgrade        2012-04-15  POINT (-744.55909 -649.35427)
# 107319  Europe/Belgrade        2012-04-16  POINT (-774.94487 -634.27526)
# 110044    Europe/Moscow        2012-01-17   POINT (781.23388 -629.54794)
#
#            distance
# 120263     2.016086
# 118318     2.122718
# 120265     3.790096
# 120267     7.159242
# 119592     9.585490
# ...             ...
# 107339   986.347951
# 107365   987.513343
# 107517   987.941905
# 107319  1001.421315
# 110044  1003.322968
#
# [9439 rows x 21 columns]

# %%
closest_cities = (
    proj_df.query(f"distance > {disaster_radius_km} and distance <= {flight_radius_km} and `feature code` != 'PPL'")
    .sort_values("population", ascending=False)
    .head(20)
)

# %%
closest_cities
# Out:
#         geonameid                  name             asciiname  \
# 13419      627907               Homyel'               Homyel'
# 118336     689558             Vinnytsya             Vinnytsya
# 118552     692194                  Sumy                  Sumy
# 118897     696643               Poltava               Poltava
# 119938     710791              Cherkasy              Cherkasy
# 119602     706369          Khmelnytskyi          Khmelnytskyi
# 118820     695594                 Rivne                 Rivne
# 119579     705812         Kropyvnytskyy         Kropyvnytskyy
# 13472      630468              Babruysk              Babruysk
# 119437     704147            Kremenchuk            Kremenchuk
# 77356      618605                 Bălţi                 Balti
# 13355      625324                 Mazyr                 Mazyr
# 13304      622428             Salihorsk             Salihorsk
# 119637     706950  Kamyianets-Podilskyy  Kamyianets-Podilskyy
# 119524     705135               Konotop               Konotop
# 118691     693942               Shostka               Shostka
# 118428     690688                  Uman                  Uman
# 119031     698625          Oleksandriya          Oleksandriya
# 13246      618806               Zhlobin               Zhlobin
# 13279      621074          Svyetlahorsk          Svyetlahorsk
#
#                                            alternatenames  latitude  \
# 13419   GME,Gomel,Gomel',Gomela,Gomelis,Gomel’,Gomeļa,...  52.43450
# 118336  VIN,Vinica,Vinicja,Vinitsa,Vinnica,Vinnicja,Vi...  49.23220
# 118552  Soemi,Soemy,Soumy,Sumad,Sumae,Sumai,Sumi,Sumio...  50.92160
# 118897  PLV,Paltava,Poltav,Poltava,Poltavae,Poltave,Po...  49.58925
# 119938  CKC,Cerkasad,Cerkasai,Cerkasi,Cerkaso,Cerkassi...  49.44452
# 119602  Chmelnyzkyj,Chmielnicki,HMJ,Hmeljnickij,Khmel'...  49.41835
# 118820  Eractum,RWN,Rivne,Rivno,Rivnė,Riwne,Rouna,Rovn...  50.62308
# 119579  Elisavet,Elisavetgrad,Elizabethgrad,Elizavetgr...  48.50834
# 13472   Babroejsk,Babruisk,Babrujsk,Babruysk,Bobruisk,...  53.13840
# 119437  KHU,Kermenchuk,Kramjanchug,Kremenchug,Kremench...  49.06253
# 77356   BZY,Balti,Baltsy,Behlc',Bel'cy,Bel'tsy,Belcai,...  47.76314
# 13355   Masyr,Mazir,Mazira,Mazyr,Mozir,Mozyr,Mozyr',Mo...  52.04950
# 13304   Chizhevichi,Saligorsk,Salihorsk,Salihorska,Sal...  52.78760
# 119637  Kam'janec'-Podil's'kij,Kamenec-Podol'skij,Kame...  48.67882
# 119524  Kanatop,Kanatyp,Konotop,Konotopa,Konotopas,ke ...  51.24032
# 118691                            Schostka,Shostka,Шостка  51.86296
# 118428  Human,Humań,Ouman,Uman,Uman',ʼwmn,ʼwmʼn,Умань,...  48.75010
# 119031  Aleksandrija,Oleksandriia,Oleksandrija,Oleksan...  48.67466
# 13246             Korpilovka,Zhlobin,Zlobin,Жлобин,Жлобін  52.89260
# 13279   Shatilki,Shatsilki,Svetlagorsk,Svetlogorsk,Svy...  52.63290
#
#         longitude feature class feature code country code  cc2  ...  \
# 13419    30.97540             P         PPLA           BY  NaN  ...
# 118336   28.46871             P         PPLA           UA  NaN  ...
# 118552   34.80029             P         PPLA           UA  NaN  ...
# 118897   34.55367             P         PPLA           UA  NaN  ...
# 119938   32.05738             P         PPLA           UA  NaN  ...
# 119602   26.97936             P         PPLA           UA  NaN  ...
# 118820   26.22743             P         PPLA           UA  NaN  ...
# 119579   32.26618             P         PPLA           UA  NaN  ...
# 13472    29.22140             P        PPLA2           BY  NaN  ...
# 119437   33.40484             P        PPLA2           UA  NaN  ...
# 77356    27.92932             P         PPLA           MD  NaN  ...
# 13355    29.24560             P        PPLA2           BY  NaN  ...
# 13304    27.54150             P        PPLA2           BY  NaN  ...
# 119637   26.58516             P        PPLA2           UA  NaN  ...
# 119524   33.20263             P        PPLA2           UA  NaN  ...
# 118691   33.46980             P        PPLA2           UA  NaN  ...
# 118428   30.21944             P        PPLA2           UA  NaN  ...
# 119031   33.11761             P        PPLA2           UA  NaN  ...
# 13246    30.02400             P        PPLA2           BY  NaN  ...
# 13279    29.73890             P        PPLA2           BY  NaN  ...
#
#        admin2 code admin3 code admin4 code population  elevation  dem  \
# 13419          NaN         NaN         NaN     480951        NaN  138
# 118336      689560         NaN         NaN     369839      248.0  260
# 118552         NaN         NaN         NaN     294456        NaN  143
# 118897      696629         NaN         NaN     288324      156.0  160
# 119938      710795         NaN         NaN     276360      110.0  111
# 119602      706375         NaN         NaN     271263      295.0  308
# 118820         NaN         NaN         NaN     255106        NaN  207
# 119579      705813         NaN         NaN     227413      113.0  114
# 13472          NaN         NaN         NaN     220517        NaN  159
# 119437      704149         NaN         NaN     220065       90.0   72
# 77356          NaN         NaN         NaN     125000        NaN  110
# 13355          NaN         NaN         NaN     112137        NaN  152
# 13304          NaN         NaN         NaN     101614        NaN  157
# 119637      707076         NaN         NaN      99755      164.0  219
# 119524         NaN         NaN         NaN      91798        NaN  142
# 118691         NaN         NaN         NaN      85432        NaN  154
# 118428      690686         NaN         NaN      83142      197.0  219
# 119031      709226         NaN         NaN      79289       99.0  103
# 13246          NaN         NaN         NaN      73089        NaN  139
# 13279          NaN         NaN         NaN      71250        NaN  142
#
#                timezone modification date                       geometry  \
# 13419      Europe/Minsk        2019-09-05     POINT (39.64401 226.29061)
# 118336      Europe/Kiev        2022-02-27  POINT (-140.11405 -128.30365)
# 118552      Europe/Kiev        2022-02-27     POINT (309.75132 67.01457)
# 118897      Europe/Kiev        2022-03-01    POINT (300.71909 -82.01112)
# 119938      Europe/Kiev        2020-05-17   POINT (120.72207 -105.14752)
# 119602      Europe/Kiev        2022-03-08  POINT (-247.58163 -103.74625)
# 118820      Europe/Kiev        2022-03-01    POINT (-294.59465 32.86138)
# 119579      Europe/Kiev        2022-03-02   POINT (138.44757 -208.87623)
# 13472      Europe/Minsk        2012-01-18    POINT (-78.40653 305.09094)
# 119437      Europe/Kiev        2022-03-02   POINT (220.09509 -144.54540)
# 77356   Europe/Chisinau        2020-06-10  POINT (-184.69641 -290.44482)
# 13355      Europe/Minsk        2018-10-26    POINT (-78.69514 183.90582)
# 13304      Europe/Minsk        2015-11-11   POINT (-192.36038 269.15726)
# 119637      Europe/Kiev        2022-03-14  POINT (-280.30757 -184.52744)
# 119524      Europe/Kiev        2019-09-05     POINT (196.19577 96.98703)
# 118691      Europe/Kiev        2014-11-05    POINT (211.94107 166.95567)
# 118428      Europe/Kiev        2020-05-16   POINT (-12.73624 -183.70564)
# 119031      Europe/Kiev        2021-07-30   POINT (200.67501 -188.46242)
# 13246      Europe/Minsk        2012-02-02    POINT (-24.81657 277.17331)
# 13279      Europe/Minsk        2014-06-27    POINT (-44.27024 248.40787)
#
#           distance
# 13419   229.736995
# 118336  189.983609
# 118552  316.917706
# 118897  311.701455
# 119938  160.093158
# 119602  268.439839
# 118820  296.421790
# 119579  250.593309
# 13472   315.004869
# 119437  263.315821
# 77356   344.196102
# 13355   200.035684
# 13304   330.829479
# 119637  335.593072
# 119524  218.859008
# 118691  269.802176
# 118428  184.146609
# 119031  275.297191
# 13246   278.282064
# 13279   252.321867
#
# [20 rows x 21 columns]

# %%
closest_cities.shape
# Out:
# (20, 21)

# %%
closest = closest_cities.copy()

# %%
# mapping and shape utils
import folium
from folium import plugins

# Create Map
map = folium.Map(location=[start_lat,start_lon], zoom_start=7)

start_m = folium.Marker([start_lat, start_lon], popup=(start_lat, start_lon), 
                        icon=folium.Icon(icon='glyphicon glyphicon-fire', color='darkred'))
start_m.add_to(map)

# Plot conflict starting points
for kk, loc in closest.iterrows():
    loc_m = folium.Marker([loc.latitude, loc.longitude], popup=loc['name'], 
                            icon=folium.Icon(icon='glyphicon glyphicon-home', color='blue'))
    loc_m.add_to(map)

# Add fullscreen button
plugins.Fullscreen().add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_26c2e83ad0514cafbbea2b78cda018a9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_26c2e83ad0514cafbbea2b78cda018a9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_26c2e83ad0514cafbbea2b78cda018a9%20%3D%20L.map%28%0A%20%2 ...
